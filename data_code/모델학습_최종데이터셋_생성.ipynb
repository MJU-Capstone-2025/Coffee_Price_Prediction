# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/캡스톤/coffee_oil_exchange_daily.csv")

# %%
df.fillna(method='ffill', inplace=True)  # 이전 값으로 대체
df.fillna(method='bfill', inplace=True)  # 다음 값으로 대체
# Out:
# <ipython-input-5-14616036d776>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)  # 이전 값으로 대체
# <ipython-input-5-14616036d776>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # 다음 값으로 대체

# %%
df = df[['Date','Coffee_Price', 'Crude_Oil_Price', 'USD_BRL']]

# %%
we = pd.read_csv("/content/drive/MyDrive/캡스톤/비수확기평균커피가격통합데이터.csv")

# %%
we.drop(columns=['Coffee_Price', 'Coffee_Price_Return','Crude_Oil_Price','USD_KRW','USD_BRL','USD_COP'], inplace=True)

# %%
df = pd.merge(df, we, on='Date', how='inner')

# %%
df = df.dropna()

# %%
df
# Out:
#             Date  Coffee_Price  Crude_Oil_Price   USD_BRL  \
# 0     2015-10-01    120.750000        44.740002  3.998800
# 1     2015-10-02    124.300003        45.540001  3.998800
# 2     2015-10-04    124.300003        45.540001  3.927500
# 3     2015-10-05    127.550003        46.259998  3.909900
# 4     2015-10-06    128.100006        48.529999  3.849000
# ...          ...           ...              ...       ...
# 2737  2025-03-17    389.350006        67.580002  5.740600
# 2738  2025-03-18    387.149994        66.900002  5.678069
# 2739  2025-03-19    394.600006        67.160004  5.672100
# 2740  2025-03-20    392.149994        68.260002  5.648100
# 2741  2025-03-21    391.399994        68.279999  5.673900
#
#       brazil_varginha_PRECTOTCORR_harvest_mean  \
# 0                                     3.604833
# 1                                     3.604833
# 2                                     3.604833
# 3                                     3.604833
# 4                                     3.604833
# ...                                        ...
# 2737                                  4.227277
# 2738                                  4.227277
# 2739                                  4.227277
# 2740                                  4.227277
# 2741                                  4.227277
#
#       brazil_carmo_de_minas_PRECTOTCORR_harvest_mean  \
# 0                                           3.354167
# 1                                           3.354167
# 2                                           3.354167
# 3                                           3.354167
# 4                                           3.354167
# ...                                              ...
# 2737                                        3.792676
# 2738                                        3.792676
# 2739                                        3.792676
# 2740                                        3.792676
# 2741                                        3.792676
#
#       brazil_patrocinio_PRECTOTCORR_harvest_mean  \
# 0                                       4.103583
# 1                                       4.103583
# 2                                       4.103583
# 3                                       4.103583
# 4                                       4.103583
# ...                                          ...
# 2737                                    3.478169
# 2738                                    3.478169
# 2739                                    3.478169
# 2740                                    3.478169
# 2741                                    3.478169
#
#       ethiopia_limu_PRECTOTCORR_harvest_mean  \
# 0                                   4.974019
# 1                                   4.974019
# 2                                   4.974019
# 3                                   4.974019
# 4                                   4.974019
# ...                                      ...
# 2737                                6.743879
# 2738                                6.743879
# 2739                                6.743879
# 2740                                6.743879
# 2741                                6.743879
#
#       ethiopia_sidamo_PRECTOTCORR_harvest_mean  \
# 0                                     3.954112
# 1                                     3.954112
# 2                                     3.954112
# 3                                     3.954112
# 4                                     3.954112
# ...                                        ...
# 2737                                  6.293224
# 2738                                  6.293224
# 2739                                  6.293224
# 2740                                  6.293224
# 2741                                  6.293224
#
#       ethiopia_yirgacheffe_PRECTOTCORR_harvest_mean  \
# 0                                          5.100327
# 1                                          5.100327
# 2                                          5.100327
# 3                                          5.100327
# 4                                          5.100327
# ...                                             ...
# 2737                                       5.990981
# 2738                                       5.990981
# 2739                                       5.990981
# 2740                                       5.990981
# 2741                                       5.990981
#
#       colombia_manizales_PRECTOTCORR_harvest_mean  \
# 0                                        3.566777
# 1                                        3.566777
# 2                                        3.566777
# 3                                        3.566777
# 4                                        3.566777
# ...                                           ...
# 2737                                     6.095267
# 2738                                     6.095267
# 2739                                     6.095267
# 2740                                     6.095267
# 2741                                     6.095267
#
#       colombia_armenia_PRECTOTCORR_harvest_mean  \
# 0                                      3.018017
# 1                                      3.018017
# 2                                      3.018017
# 3                                      3.018017
# 4                                      3.018017
# ...                                         ...
# 2737                                   5.461152
# 2738                                   5.461152
# 2739                                   5.461152
# 2740                                   5.461152
# 2741                                   5.461152
#
#       colombia_pereira_PRECTOTCORR_harvest_mean
# 0                                      3.566777
# 1                                      3.566777
# 2                                      3.566777
# 3                                      3.566777
# 4                                      3.566777
# ...                                         ...
# 2737                                   6.095267
# 2738                                   6.095267
# 2739                                   6.095267
# 2740                                   6.095267
# 2741                                   6.095267
#
# [2742 rows x 13 columns]

# %%
df.to_csv("Coffee_Price_Weather.csv", index=False)
